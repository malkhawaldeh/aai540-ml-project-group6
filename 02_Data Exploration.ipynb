# %%
# Data exploration

# %%
# The DataFrame 'df_from_athena' should already be in memory from the previous step.

# Check the shape of the DataFrame
print("Shape of the DataFrame:", df_from_athena.shape)

# Examine data types and identify unexpected types
print("\nData Types:")
df_from_athena.info()

# Identify missing values
missing_values = df_from_athena.isnull().sum()
missing_percentage = (missing_values / len(df_from_athena)) * 100
print("\nMissing Values (Count):\n", missing_values[missing_values > 0])
print("\nMissing Value (Percentage):\n", missing_percentage[missing_percentage > 0])

# Descriptive statistics for numerical columns
numerical_cols = df_from_athena.select_dtypes(include=['number'])
if not numerical_cols.empty:
    print("\nDescriptive Statistics for Numerical Columns:\n")
    display(numerical_cols.describe())
else:
    print("\nNo numerical columns found.")

# Analyze frequency distribution for categorical columns
categorical_cols = df_from_athena.select_dtypes(include=['object'])
print("\n--- Frequency Distribution for Categorical Columns ---")
for col in categorical_cols.columns:
    print(f"\nValue Counts for '{col}':\n{df_from_athena[col].value_counts().head(10)}") # Show top 10 for brevity
# Out:
# Shape of the DataFrame: (1000, 28)
#
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   dr_no           1000 non-null   int64
#  1   date rptd       1000 non-null   object
#  2   date occ        1000 non-null   object
#  3   time occ        1000 non-null   int64
#  4   area            1000 non-null   int64
#  5   area name       1000 non-null   object
#  6   rpt dist no     1000 non-null   int64
#  7   part 1-2        1000 non-null   int64
#  8   crm cd          1000 non-null   int64
#  9   crm cd desc     1000 non-null   object
#  10  mocodes         831 non-null    object
#  11  vict age        827 non-null    float64
#  12  vict sex        834 non-null    object
#  13  vict descent    832 non-null    object
#  14  premis cd       814 non-null    float64
#  15  premis desc     998 non-null    object
# ...
